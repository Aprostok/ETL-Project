# %% [markdown]
# ### EnergyETL

# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# read csv file
file_path = "Resources/us_potential_energy.csv"

# create the data frame 
energy_df = pd.read_csv(file_path)
energy_df.head()
# Out:
#        States  urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# 0     Alabama                    35850                      20
# 1      Alaska                      166                       0
# 2     Arizona                   121305                      52
# 3    Arkansas                    28960                      15
# 4  California                   246008                     111
#
#    urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  ruralUtilityScalePV_GW  \
# 0                      426                  3706838                    2114
# 1                        2                  8282976                    9005
# 2                     1096                 11867693                    5147
# 3                      332                  4986388                    2747
# 4                     2320                  8855917                    4010
#
#    ruralUtilityScalePV_km2  rooftopPV_GWh  rooftopPV_GW   CSP_GWh  ...  \
# 0                    44058        15475.0            12         0  ...
# 1                   187608            NaN             1         0  ...
# 2                   107230        22736.0            14  12544333  ...
# 3                    57239         8484.0             6         0  ...
# 4                    83549       106411.0            75   8490916  ...
#
#    biopowerGaseous_GWh  biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# 0                 1533                   0                      326186
# 1                   61                   0                       13156
# 2                  837                   0                      178188
# 3                 1063                   0                      226178
# 4                15510                   1                     3300211
#
#    geothermalHydrothermal_GWh  geothermalHydrothermal_GW  EGSGeothermal_GWh  \
# 0                           0                          0           535489.0
# 1                       15437                          1                NaN
# 2                        8329                          1          1239147.0
# 3                           0                          0           628621.0
# 4                      130921                         16          1344179.0
#
#    EGSGeothermal_GW  hydropower_GWh  hydropower_GW  hydropower_countOfSites
# 0              67.0            4102              0                     2435
# 1               NaN           23675              5                     3053
# 2             157.0            1303              0                     1958
# 3              79.0            6093              1                     3268
# 4             170.0           30023              6                     9692
#
# [5 rows x 31 columns]

# %%
# select the columns
energy_df = energy_df[["States", "urbanUtilityScalePV_GWh","ruralUtilityScalePV_GWh","rooftopPV_GWh", "CSP_GWh","onshoreWind_GWh","offshoreWind_GWh", "biopowerSolid_GWh", "biopowerGaseous_GWh", "geothermalHydrothermal_GWh", "EGSGeothermal_GWh", "hydropower_GWh"]]
                     
# display the new dataframe
energy_df.head()
# Out:
#        States  urbanUtilityScalePV_GWh  ruralUtilityScalePV_GWh  \
# 0     Alabama                    35850                  3706838
# 1      Alaska                      166                  8282976
# 2     Arizona                   121305                 11867693
# 3    Arkansas                    28960                  4986388
# 4  California                   246008                  8855917
#
#    rooftopPV_GWh   CSP_GWh  onshoreWind_GWh  offshoreWind_GWh  \
# 0        15475.0         0              283               0.0
# 1            NaN         0          1373433               NaN
# 2        22736.0  12544333            26036               NaN
# 3         8484.0         0            22892               NaN
# 4       106411.0   8490916            89862         2662579.0
#
#    biopowerSolid_GWh  biopowerGaseous_GWh  geothermalHydrothermal_GWh  \
# 0              11193                 1533                           0
# 1                513                   61                       15437
# 2               1087                  837                        8329
# 3              14381                 1063                           0
# 4              12408                15510                      130921
#
#    EGSGeothermal_GWh  hydropower_GWh
# 0           535489.0            4102
# 1                NaN           23675
# 2          1239147.0            1303
# 3           628621.0            6093
# 4          1344179.0           30023

# %%
# rename the columns
energy_df.columns=["States", "Urban_Solar", "Rural_Solar", "Rooftop_Solar", "CSP_Solar", "Onshore_Wind", "Offshore_Wind", "Biopower_Solid", "Biopower_Gaseous", "Geothermal_Hydrothermal", "EGS_Geothermal", "Hydropower"]
energy_df.head()
# Out:
#        States  Urban_Solar  Rural_Solar  Rooftop_Solar  CSP_Solar  \
# 0     Alabama        35850      3706838        15475.0          0
# 1      Alaska          166      8282976            NaN          0
# 2     Arizona       121305     11867693        22736.0   12544333
# 3    Arkansas        28960      4986388         8484.0          0
# 4  California       246008      8855917       106411.0    8490916
#
#    Onshore_Wind  Offshore_Wind  Biopower_Solid  Biopower_Gaseous  \
# 0           283            0.0           11193              1533
# 1       1373433            NaN             513                61
# 2         26036            NaN            1087               837
# 3         22892            NaN           14381              1063
# 4         89862      2662579.0           12408             15510
#
#    Geothermal_Hydrothermal  EGS_Geothermal  Hydropower
# 0                        0        535489.0        4102
# 1                    15437             NaN       23675
# 2                     8329       1239147.0        1303
# 3                        0        628621.0        6093
# 4                   130921       1344179.0       30023

# %%
# change NaN values to 0
energy_df.fillna(0, inplace=True)
energy_df.head()
# Out:
#        States  Urban_Solar  Rural_Solar  Rooftop_Solar  CSP_Solar  \
# 0     Alabama        35850      3706838        15475.0          0
# 1      Alaska          166      8282976            0.0          0
# 2     Arizona       121305     11867693        22736.0   12544333
# 3    Arkansas        28960      4986388         8484.0          0
# 4  California       246008      8855917       106411.0    8490916
#
#    Onshore_Wind  Offshore_Wind  Biopower_Solid  Biopower_Gaseous  \
# 0           283            0.0           11193              1533
# 1       1373433            0.0             513                61
# 2         26036            0.0            1087               837
# 3         22892            0.0           14381              1063
# 4         89862      2662579.0           12408             15510
#
#    Geothermal_Hydrothermal  EGS_Geothermal  Hydropower
# 0                        0        535489.0        4102
# 1                    15437             0.0       23675
# 2                     8329       1239147.0        1303
# 3                        0        628621.0        6093
# 4                   130921       1344179.0       30023

# %%
#output clean data frame to csv
potential_energy = "Resources/us_potential_energy(clean).csv"
energy_df.to_csv(potential_energy,index=False)

# %% [markdown]
# ### Scrape Wikipedia for the US Census Population Estimates

# %%
# Store the Wikipedia URL
wiki_url = "https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population#cite_note-5"

# Use Pandas to scrape Wikipedia page for tables
wiki_tables = pd.read_html(wiki_url)

# Grab the first table
pop_est_df = wiki_tables[0]

# Grab the State & Population est. for 2018
pop_est_df = pop_est_df[['State', 'Estimate, July 1, 2019[5]']]

# Rename the columns
pop_est_df = pop_est_df.rename(columns={"Name": "State", "Estimate, July 1, 2019[5]": "Population"})

# Drop the Territories
pop_est_df = pop_est_df[0:52]

# Display the new DataFrame
pop_est_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-91976e3b8abd> in <module>
#       9
#      10 # Grab the State & Population est. for 2018
# ---> 11 pop_est_df = pop_est_df[['State', 'Estimate, July 1, 2019[5]']]
#      12
#      13 # Rename the columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1140         # if it cannot handle:
#    1141         indexer, keyarr = ax._convert_listlike_indexer(key,
# -> 1142                                                        kind=self.name)
#    1143         # We only act on all found values:
#    1144         if indexer is not None and (indexer != -1).all():
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _convert_listlike_indexer(self, keyarr, kind)
#    2134             mask = check == -1
#    2135             if mask.any():
# -> 2136                 raise KeyError('%s not in index' % keyarr[mask])
#    2137
#    2138         return indexer, keyarr
#
# KeyError: "['Estimate, July 1, 2019[5]'] not in index"

# %%
# Read in Energy Consumption csv
tot_consum_csv = "Resources/total_energy_consumed.csv"

# Create the Consumption DataFrame
tot_consum_df = pd.read_csv(tot_consum_csv)

# Join Population and Total Energy Consumed DataFrames
tot_consum_df = tot_consum_df.merge(pop_est_df, on='State',how="inner")

#convert BTU's to Gigawatt hours
tot_energy_gwh = tot_consum_df['Total_Energy_Consumed'] * 1000000 * 0.00000000029 * tot_consum_df['Population']

#add Gigawatt hours to dataframe
tot_consum_df['Total_Energy_Consumed_Gwh'] = tot_energy_gwh
tot_consum_df = tot_consum_df[['Rank','State','Total_Energy_Consumed_Gwh']]
tot_consum_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-b966757127bc> in <module>
#       6
#       7 # Join Population and Total Energy Consumed DataFrames
# ----> 8 tot_consum_df = tot_consum_df.merge(pop_est_df, on='State',how="inner")
#       9
#      10 #convert BTU's to Gigawatt hours
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     831                         if rk is not None:
#     832                             right_keys.append(
# --> 833                                 right._get_label_or_level_values(rk))
#     834                         else:
#     835                             # work-around for merge_asof(right_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1723                              .format(key=key,
#    1724                                      label_axis_name=label_axis_name,
# -> 1725                                      multi_message=multi_message))
#    1726
#    1727         return values
#
# ValueError: The column label 'State' is not unique.
# For a multi-index, the label must be a tuple with elements corresponding to each level.

# %%
#connect to database
from config import sqldb_connect
engine = create_engine(sqldb_connect)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-201df2d09bfe> in <module>
#       1 #connect to database
# ----> 2 from config import sqldb_connect
#       3 engine = create_engine(sqldb_connect)
#
# ModuleNotFoundError: No module named 'config'

# %%
#copy dataframes into database tables
pop_est_df.to_sql('state_population', con=engine, if_exists='replace')
energy_df.to_sql('energy_renewable', con=engine, if_exists='replace')
tot_consum_df.to_sql('energy_consumption', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7f6c5da52ba6> in <module>
#       1 #copy dataframes into database tables
# ----> 2 pop_est_df.to_sql('state_population', con=engine, if_exists='replace')
#       3 energy_df.to_sql('energy_renewable', con=engine, if_exists='replace')
#       4 tot_consum_df.to_sql('energy_consumption', con=engine, if_exists='replace')
#
# NameError: name 'engine' is not defined

# %%
#calcuate total renewable energy potential & add to master dataframe
renewable_master_df = energy_df.set_index('State')
renewable_master_sum = renewable_master_df.sum(axis=1)
renewable_master_df = pd.DataFrame(renewable_master_sum)
renewable_master_df = renewable_master_df.rename(columns={0:'Total Renewable'})
energy_master_df = tot_consum_df.merge(renewable_master_df, on='State')
energy_master_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-d0abdac52990> in <module>
#       1 #calcuate total renewable energy potential & add to master dataframe
# ----> 2 renewable_master_df = energy_df.set_index('State')
#       3 renewable_master_sum = renewable_master_df.sum(axis=1)
#       4 renewable_master_df = pd.DataFrame(renewable_master_sum)
#       5 renewable_master_df = renewable_master_df.rename(columns={0:'Total Renewable'})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4176                 names.append(None)
#    4177             else:
# -> 4178                 level = frame[col]._values
#    4179                 names.append(col)
#    4180                 if drop:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'

# %%
#calcuate difference in renewable energy potential & consumption
#add to master dataframe
energy_diff = energy_master_df['Total Renewable'] - energy_master_df['Total_Energy_Consumed_Gwh']
energy_master_df['Energy Difference'] = energy_diff

energy_master_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f1aff1625f01> in <module>
#       1 #calcuate difference in renewable energy potential & consumption
#       2 #add to master dataframe
# ----> 3 energy_diff = energy_master_df['Total Renewable'] - energy_master_df['Total_Energy_Consumed_Gwh']
#       4 energy_master_df['Energy Difference'] = energy_diff
#       5
#
# NameError: name 'energy_master_df' is not defined

# %%
#output data frame to csv
energy_compare = "Resources/energy_totals_comparison.csv"
energy_master_df.to_csv(energy_compare,index=False)

#copy dataframe into database tables
energy_master_df.to_sql('energy_compare', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-84576c05f180> in <module>
#       1 #output data frame to csv
#       2 energy_compare = "Resources/energy_totals_comparison.csv"
# ----> 3 energy_master_df.to_csv(energy_compare,index=False)
#       4
#       5 #copy dataframe into database tables
#
# NameError: name 'energy_master_df' is not defined

# %%
#Query database to find states with negative energy difference values
not_100_renew = engine.execute('select "State" from energy_compare where "Energy Difference" < 0').fetchall()
not_100_renew = [states[0] for states in not_100_renew]

#output query results
print('The following states do not have sufficient potential sources of renewable energy to meet their current energy consumption:')
for state in not_100_renew:
    print(state)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-011a9bac28d1> in <module>
#       1 #Query database to find states with negative energy difference values
# ----> 2 not_100_renew = engine.execute('select "State" from energy_compare where "Energy Difference" < 0').fetchall()
#       3 not_100_renew = [states[0] for states in not_100_renew]
#       4
#       5 #output query results
#
# NameError: name 'engine' is not defined
